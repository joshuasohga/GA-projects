# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# In this project, my objective is to analyse and find trends in the SAT and ACT participation rates and subject scores in 2017 and 2018. I am to assume the role of a College Board employee, and will be part of a team that tracks statewide participation and provide recommendations on where money can be best spent to improve SAT participation rates.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# In a 2017 news article published by [EducationWeek](https://www.edweek.org/teaching-learning/in-race-for-test-takers-act-outscores-sat-for-now/2017/05), ACT had been the most popular test to predict college performance since 2012. Below is an image showing the popularity trend between ACT and SAT from 1986 to 2016:<br>
# <img src="https://epe.brightspotcdn.com/dims4/default/1252f2e/2147483647/strip/true/crop/280x130+0+0/resize/280x130!/format/webp/quality/90/?url=https%3A%2F%2Fepe-brightspot.s3.amazonaws.com%2F5a%2Fe5%2Fcf9797cc8f082dd175715ad77c00%2F32-sr-assessment-sat-act-graph-c1s.jpg" align="center/"><br>
# <center>Source: ACT Inc. and College Board</center><br>
# Given the datasets chosen above, we can verify if this is truly the case. The aim of this project also seeks to conduct a comparison in respect to the participation rates and mean scores attained by each state to uncover and understand the trends.

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# The datasets that have been chosen for this project are as follows:
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State (includes participation rate, mean scores for English, Math, Reading, Science and Composite scores for all the US states.)
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State (includes participation rate and mean scores Composite scores for all the US states.)
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State (includes participation rate, mean scores for Evidence-Based Reading and Writing, Math and Total scores for all the US states.)
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State (includes participation rate, mean scores for Evidence-Based Reading and Writing, Math and Total scores for all the US states.)

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# https://www.edweek.org/teaching-learning/in-race-for-test-takers-act-outscores-sat-for-now/2017/05 - ACT overtakes SAT in popularity
#
# https://epe.brightspotcdn.com/dims4/default/1252f2e/2147483647/strip/true/crop/280x130+0+0/resize/280x130!/format/webp/quality/90/?url=https%3A%2F%2Fepe-brightspot.s3.amazonaws.com%2F5a%2Fe5%2Fcf9797cc8f082dd175715ad77c00%2F32-sr-assessment-sat-act-graph-c1s.jpg - Image of test-taking trend between ACT and SAT from 1986 to 2016
#
# https://delawarepta.org/free-sat-registration-now-open-for-public-school-juniors/ - Delaware offers free SAT registration (2011)
#
# https://testive.com/state-sat-act/ - States that require ACT/SAT

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean(sample):
    return sum(sample)/len(sample)

list_of_numbers = [1, 5, 8, 10, 12] # 5 numbers, total of 36

mean(list_of_numbers)
# Out:
# 7.2

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_dev1(array):
    n = len(array)
    mean = sum(array) / n
    sumsq = sum(v * v for v in array)
    return round((sumsq / n - mean * mean) ** 0.5,2) #round it to 2 decimal places

ls = [1, 5, 8, 10, 15]

std_dev1(ls)
# Out:
# 4.71

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def pct_to_float(val):
    
    val = val.replace("%", "") # remove the % sign
    val = float(val)/100 # to obtain the percentage in float value
    
    return val

x = pct_to_float("50%")
print(x)

def float_to_pct(val):
    
    val = val*100 #in case we may need to use the percentages again
    
    return val

y = float_to_pct(0.5)
print(y)
# Out:
# 0.5
# 50.0

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

df_sat2017 = pd.read_csv("../data/sat_2017.csv")
df_act2017 = pd.read_csv("../data/act_2017.csv")
df_sat2018 = pd.read_csv("../data/sat_2018.csv")
df_act2018 = pd.read_csv("../data/act_2018.csv")

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
#
#
#
#
#
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.

# %% [markdown]
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %% [markdown]
# ## 2017 Data

# %%
#first 5 rows of SAT 2017 dataframe.
df_sat2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
df_sat2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#first 5 rows of ACT 2017 dataframe.
df_act2017.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#data types
df_act2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
#identify and find the foreign object
df_act2017[["State","Composite"]].tail()
# Out:
#             State Composite
# 47       Virginia      23.8
# 48     Washington      21.9
# 49  West Virginia      20.4
# 50      Wisconsin      20.5
# 51        Wyoming     20.2x

# %% [markdown]
# 2. Check for missing values.

# %%
pd.isnull(df_sat2017).sum() #ensuring no null values
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
#first 5 rows of ACT 2017 dataframe.
pd.isnull(df_act2017).sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
df_sat2017.describe() #min value 52 when the Mean is 547 for Math. Erroneous value entered for Maryland?
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
df_act2017.describe() #min value for Science seems to be abnormally low as well. Again, this is happening to the Maryland entry.
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# Tracing the source of these datasets back to https://nces.ed.gov/, it appears that there indeed are erroneous values keyed in for the SAT Math and ACT Science scores for Maryland. And now that we have identified the errors, below are the amendments to be made to correct the inputs.

# %% [markdown]
# 4. Fix any errors you identified in steps 2-3.

# %%
df_sat2017.loc[20,["Math"]] = 524 # correct the score to 524
df_sat2017.loc[20,"Math"] #confirm that the amendment has been made to the correct row
# Out:
# 524

# %%
df_act2017.loc[21,["Science"]] = 23.2
df_act2017.loc[21,"Science"]
# Out:
# 23.2

# %% [markdown]
# 5. Display the data types of each feature.

# %%
display("SAT",df_sat2017.dtypes)
display("ACT",df_act2017.dtypes) #Composite should not be an object type - is there an error here?
# Out:
# 'SAT'
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# 'ACT'
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# Looking into the ACT 2017 dataset, we identified the reason for Composite score to be classified under the Object type: the Composite score for Wyoming is erroneously entered as 20.2x.

# %%
df_act2017.loc[51,["Composite"]] = 20.2

df_act2017["Composite"] = df_act2017["Composite"].astype(float) #converts all values to float type.

df_act2017.dtypes #check if the change has been successfully applied.
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.

# %%
df_sat2017["Participation"] = df_sat2017["Participation"].apply(pct_to_float)
df_act2017["Participation"] = df_act2017["Participation"].apply(pct_to_float)

display("SAT",df_sat2017.dtypes)
display("ACT",df_act2017.dtypes)
# Out:
# 'SAT'
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
# 'ACT'
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
df_sat2017.rename(columns = {"State":"sat_state_2017",
                             "Participation":"sat_participation_2017",
                             "Evidence-Based Reading and Writing":"sat_ebrw_2017",
                             "Math":"sat_math_2017",
                             "Total":"sat_total_2017"}, inplace = True)
df_sat2017.head()
# Out:
#   sat_state_2017  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 0        Alabama                    0.05            593            572
# 1         Alaska                    0.38            547            533
# 2        Arizona                    0.30            563            553
# 3       Arkansas                    0.03            614            594
# 4     California                    0.53            531            524
#
#    sat_total_2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %%
df_act2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
df_act2017.rename(columns = {
    "State":"act_state_2017",
    "Participation":"act_participation_2017",
    "English":"act_english_2017",
    "Math":"act_math_2017",
    "Reading":"act_reading_2017",
    "Science":"act_science_2017",
    "Composite":"act_composite_2017"}, inplace = True)

# %% [markdown]
# 8. Drop unnecessary rows (if needed)

# %%
#dropping the entire row of National data since it's irrelevant
df_act2017.drop(index = 0, axis = 0,inplace = True)

#verify the change has been applied
df_act2017.head()
# Out:
#   act_state_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 1        Alabama                    1.00              18.9           18.4
# 2         Alaska                    0.65              18.7           19.8
# 3        Arizona                    0.62              18.6           19.8
# 4       Arkansas                    1.00              18.9           19.0
# 5     California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %% [markdown]
# ## 2018 Data

# %%
df_sat2018.head(5) #first 5 rows of SAT 2018 dataframe.
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
df_sat2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_act2018.head(5) #first 5 rows of ACT 2018 dataframe.
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act2018
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
df_act2018.info() #detected an extra row in this dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Since it is a relatively small dataset, through observation we find that there is a duplicate in row 19 and 20 - thus we will remove the entry after the first (row 20).

# %%
df_act2018.drop_duplicates(subset="State", keep='first', inplace=True)

df_act2018 = df_act2018.reset_index()

# %%
df_act2018 #verify that the duplicate has been removed.
# Out:
#     index                 State Participation  Composite
# 0       0               Alabama          100%       19.1
# 1       1                Alaska           33%       20.8
# 2       2               Arizona           66%       19.2
# 3       3              Arkansas          100%       19.4
# 4       4            California           27%       22.7
# 5       5              Colorado           30%       23.9
# 6       6           Connecticut           26%       25.6
# 7       7              Delaware           17%       23.8
# 8       8  District of columbia           32%       23.6
# 9       9               Florida           66%       19.9
# 10     10               Georgia           53%       21.4
# 11     11                Hawaii           89%       18.9
# 12     12                 Idaho           36%       22.3
# 13     13              Illinois           43%       23.9
# 14     14               Indiana           32%       22.5
# ...

# %%
pd.isnull(df_sat2018).sum() #no null values.
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
pd.isnull(df_act2018).sum()
# Out:
# index            0
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
df_sat2018.describe() #the values seem normal here
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
df_act2018
# Out:
#     index                 State Participation  Composite
# 0       0               Alabama          100%       19.1
# 1       1                Alaska           33%       20.8
# 2       2               Arizona           66%       19.2
# 3       3              Arkansas          100%       19.4
# 4       4            California           27%       22.7
# 5       5              Colorado           30%       23.9
# 6       6           Connecticut           26%       25.6
# 7       7              Delaware           17%       23.8
# 8       8  District of columbia           32%       23.6
# 9       9               Florida           66%       19.9
# 10     10               Georgia           53%       21.4
# 11     11                Hawaii           89%       18.9
# 12     12                 Idaho           36%       22.3
# 13     13              Illinois           43%       23.9
# 14     14               Indiana           32%       22.5
# ...

# %%
df_act2018.describe() #the values seem normal here
# Out:
#            index  Composite
# count  51.000000  51.000000
# mean   25.607843  21.496078
# std    15.285390   2.111583
# min     0.000000  17.700000
# 25%    12.500000  19.950000
# 50%    26.000000  21.300000
# 75%    38.500000  23.650000
# max    51.000000  25.600000

# %% [markdown]
# 9. Merge dataframes that can be merged.

# %%
display("SAT",df_sat2018.dtypes)
display("ACT",df_act2018.dtypes)
# Out:
# 'SAT'
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# 'ACT'
# index              int64
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
#convert the participation rates into float values
df_sat2018["Participation"] = df_sat2018["Participation"].apply(strtopercentage)
df_act2018["Participation"] = df_act2018["Participation"].apply(strtopercentage)

# %%
#verify the changes have been applied
display("SAT",df_sat2018.dtypes)
display("ACT",df_act2018.dtypes)
# Out:
# 'SAT'
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
# 'ACT'
# index              int64
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
df_sat2018.rename(columns = {"State":"sat_state_2018",
                             "Participation":"sat_participation_2018",
                             "Evidence-Based Reading and Writing":"sat_ebrw_2018",
                             "Math":"sat_math_2018",
                             "Total":"sat_total_2018"}, inplace = True)

#verify the renaming changes have been applied
df_sat2018.head()
# Out:
#   sat_state_2018  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 0        Alabama                    0.06            595            571
# 1         Alaska                    0.43            562            544
# 2        Arizona                    0.29            577            572
# 3       Arkansas                    0.05            592            576
# 4     California                    0.60            540            536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
df_act2018.rename(columns = {
    "State":"act_state_2018",
    "Participation":"act_participation_2018",
    "Composite":"act_composite_2018"}, inplace = True)

#verify the renaming changes have been applied
df_act2018.reset_index
# Out:
# <bound method DataFrame.reset_index of     index        act_state_2018  act_participation_2018  act_composite_2018
# 0       0               Alabama                    1.00                19.1
# 1       1                Alaska                    0.33                20.8
# 2       2               Arizona                    0.66                19.2
# 3       3              Arkansas                    1.00                19.4
# 4       4            California                    0.27                22.7
# 5       5              Colorado                    0.30                23.9
# 6       6           Connecticut                    0.26                25.6
# 7       7              Delaware                    0.17                23.8
# 8       8  District of columbia                    0.32                23.6
# 9       9               Florida                    0.66                19.9
# 10     10               Georgia                    0.53                21.4
# ...

# %% [markdown]
# ## Merging the 2017 and 2018 SAT/ACT data into a single dataframe

# %%
sat_act_2017 = pd.merge(df_sat2017, df_act2017, left_on="sat_state_2017", right_on="act_state_2017", how="inner")

#save the merged 2017 data into another csv file
sat_act_2017.to_csv("../data/sat_act_2017.csv")

#verify that the merge is correct
sat_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sat_state_2017          51 non-null     object
#  1   sat_participation_2017  51 non-null     float64
#  2   sat_ebrw_2017           51 non-null     int64
#  3   sat_math_2017           51 non-null     int64
#  4   sat_total_2017          51 non-null     int64
#  5   act_state_2017          51 non-null     object
#  6   act_participation_2017  51 non-null     float64
#  7   act_english_2017        51 non-null     float64
#  8   act_math_2017           51 non-null     float64
#  9   act_reading_2017        51 non-null     float64
#  10  act_science_2017        51 non-null     float64
#  11  act_composite_2017      51 non-null     float64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 5.2+ KB

# %%
df_sat2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sat_state_2018          51 non-null     object
#  1   sat_participation_2018  51 non-null     float64
#  2   sat_ebrw_2018           51 non-null     int64
#  3   sat_math_2018           51 non-null     int64
#  4   sat_total_2018          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# 11. Save your cleaned and merged dataframes as csv files.

# %%
sat_act_2018 = pd.merge(df_sat2018, df_act2018, left_index = True, right_index = True)

#save the merged 2018 data into another csv file
sat_act_2018.to_csv("../data/sat_act_2018.csv")

#verify that the merge is correct
sat_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sat_state_2018          51 non-null     object
#  1   sat_participation_2018  51 non-null     float64
#  2   sat_ebrw_2018           51 non-null     int64
#  3   sat_math_2018           51 non-null     int64
#  4   sat_total_2018          51 non-null     int64
#  5   index                   51 non-null     int64
#  6   act_state_2018          51 non-null     object
#  7   act_participation_2018  51 non-null     float64
#  8   act_composite_2018      51 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 3.7+ KB

# %%
#merge the 2017 and 2018 SAT/ACT dataframes together
sat_act_final = pd.merge(sat_act_2017, sat_act_2018, left_index = True, right_index = True)

#save the consolidated 2017/2018 data into another csv file
sat_act_final.to_csv("../data/sat_act_final.csv")

sat_act_final[["sat_state_2017","sat_participation_2017","sat_participation_2018","sat_total_2017","sat_total_2018"]].iloc[[5,13]]
# Out:
#    sat_state_2017  sat_participation_2017  sat_participation_2018  \
# 5        Colorado                    0.11                    1.00
# 13       Illinois                    0.09                    0.99
#
#     sat_total_2017  sat_total_2018
# 5             1201            1025
# 13            1115            1019

# %%
#replicate a new State column
sat_act_final['state'] = sat_act_final['sat_state_2017']

#set the state as our index instead
sat_act_final.set_index("state", inplace = True)

#drop the other state columns to remove duplicates
sat_act_final.drop(['sat_state_2017','act_state_2017','sat_state_2018','act_state_2018','index'], axis = 1, inplace = True)

#verify the change is applied correctly
sat_act_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sat_participation_2017  51 non-null     float64
#  1   sat_ebrw_2017           51 non-null     int64
#  2   sat_math_2017           51 non-null     int64
#  3   sat_total_2017          51 non-null     int64
#  4   act_participation_2017  51 non-null     float64
#  5   act_english_2017        51 non-null     float64
#  6   act_math_2017           51 non-null     float64
#  7   act_reading_2017        51 non-null     float64
#  8   act_science_2017        51 non-null     float64
#  9   act_composite_2017      51 non-null     float64
#  10  sat_participation_2018  51 non-null     float64
#  11  sat_ebrw_2018           51 non-null     int64
#  12  sat_math_2018           51 non-null     int64
#  13  sat_total_2018          51 non-null     int64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state_sat_2017**<br>**state_act_2017**|*object*|ACT/SAT|The state the data is based on for the ACT and SAT tests taken in 2017.|
# |**state_sat_2018**<br>**state_act_2018**|*object*|ACT/SAT|The state the data is based on for the ACT and SAT tests taken in 2017.|
# |**sat_participation_2017**<br>**act_participation_2017**|*float*|ACT/SAT|The participation rates for all ACT and SAT tests in 2017.
# |**sat_ebrw_2017**<br>**sat_ebrw_2018**|*integer*|SAT|The average score of all the tests taken for Evidence-Based Reading and Writing in 2017/2018.|
# |**sat_math_2017**<br>**sat_math_2018**|*integer*|SAT|The average score of all the tests taken for Math in 2017/2018.
# |**sat_total_2017**<br>**sat_total_2018**|*integer*|SAT|The total average score of the Evidence-Based Reading and Writing and Math sections in 2017/2018.|
# |**act_english_2017**|*float*|ACT|The average score of all the tests taken for English in 2017.|
# |**act_math_2017**|*float*|ACT|The average score of all the tests taken for Math in 2017.|
# |**act_reading_2017**|*float*|ACT|The average score of all the tests taken for Reading in 2017.|
# |**act_science_2017**|*float*|ACT|The average score of all the tests taken for Science in 2017.|
# |**act_composite_2017**|*float*|ACT|The total average score of the English, Math, Reading and Science sections taken in 2017.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sd = {x: std_dev1(sat_act_final[x]) for x in sat_act_final}

sd #rounded to 2 decimal places
# Out:
# {'sat_participation_2017': 0.35,
#  'sat_ebrw_2017': 45.22,
#  'sat_math_2017': 46.66,
#  'sat_total_2017': 91.58,
#  'act_participation_2017': 0.32,
#  'act_english_2017': 2.33,
#  'act_math_2017': 1.96,
#  'act_reading_2017': 2.05,
#  'act_science_2017': 1.72,
#  'act_composite_2017': 2.0,
#  'sat_participation_2018': 0.37,
#  'sat_ebrw_2018': 47.03,
#  'sat_math_2018': 47.3,
#  'sat_total_2018': 93.23,
#  'act_participation_2018': 0.34,
#  'act_composite_2018': 2.09}

# %% [markdown]
# #### States with the highest/lowest participation rates (SAT/ACT)
# In 2017, SAT participation rates were the highest at 100% from 4 states: <b>District of Columbia</b>, <b>Michigan</b>, <b>Connecticut</b> and <b>Delaware</b>. On the other hand, ACT participation rates at 100% were more than 4 times higher than SAT with <b>17</b> states, indicating that there were more states then that mandated the ACT in 2017 and 2018. In 2018, the participation rates remained constant for both ACT and SAT at the aforementioned values.
#
# The lowest SAT participation rates were observed in <b>North Dakota (2%)</b>, <b>Mississipi (2%)</b> and <b>Iowa (2%)</b> in 2017. In 2018 the lowest participation rates were observed in <b>North Dakota (2%)</b>, <b>Wyoming (3%)</b> and <b>South Dakota (3%)</b>. As for the ACT participation rates, the lowest were observed in <b>Maine (8%)</b>, <b>New Hampshire (18%)</b> and <b>Delaware (18%)</b> in 2017, followed by <b>Maine (7%)</b>, <b>Rhode Island (15%)</b> and <b>New Hampshire (16%)</b> in 2018.

# %%
#print out the number of states with 100% SAT participation rate
print("The number of states with 100% participation rate is", str(np.sum(sat_act_final['sat_participation_2017'] == 1)))

#verify that the number of states is indeed 4 by calling the dataframe head
display(sat_act_final.sort_values(by = ['sat_participation_2017'], ascending = False).head())
# Out:
# The number of states with 100% participation rate is 4
#                       sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# state
# District of Columbia                    1.00            482            468
# Michigan                                1.00            509            495
# Connecticut                             1.00            530            512
# Delaware                                1.00            503            492
# New Hampshire                           0.96            532            520
#
#                       sat_total_2017  act_participation_2017  \
# state
# District of Columbia             950                    0.32
# Michigan                        1005                    0.29
# Connecticut                     1041                    0.31
# Delaware                         996                    0.18
# New Hampshire                   1052                    0.18
#
#                       act_english_2017  act_math_2017  act_reading_2017  \
# ...

# %%
#print out the number of states with 100% ACT participation rate
print("The number of states with 100% participation rate is", str(np.sum(sat_act_final['act_participation_2017'] == 1)))

#verify that the number of states is indeed 17 by calling the dataframe head(18 to check for any erroneous omissions)
sat_act_final.sort_values(by=['act_participation_2017'],ascending=False).head(18)
# Out:
# The number of states with 100% participation rate is 17
#                 sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# state
# Alabama                           0.05            593            572
# Kentucky                          0.04            631            616
# Wisconsin                         0.03            642            649
# Utah                              0.03            624            614
# Tennessee                         0.05            623            604
# South Carolina                    0.50            543            521
# Oklahoma                          0.07            530            517
# North Carolina                    0.49            546            535
# Nevada                            0.26            563            553
# Montana                           0.10            605            591
# Mississippi                       0.02            634            607
# Minnesota                         0.03            644            651
# ...

# %%
print("The number of states with 100% ACT participation rate in 2018 is",str(np.sum(sat_act_final['act_participation_2018'] == 1)))

sat_act_final.sort_values(by=['act_participation_2018'],ascending=False).head(18)
# Out:
# The number of states with 100% ACT participation rate in 2018 is 17
#                 sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# state
# Alabama                           0.05            593            572
# Kentucky                          0.04            631            616
# Wisconsin                         0.03            642            649
# Utah                              0.03            624            614
# Tennessee                         0.05            623            604
# South Carolina                    0.50            543            521
# Oklahoma                          0.07            530            517
# Ohio                              0.12            578            570
# North Carolina                    0.49            546            535
# Nevada                            0.26            563            553
# Nebraska                          0.03            629            625
# ...

# %%
print("The number of states with 100% SAT participation rate is",str(np.sum(sat_act_final['sat_participation_2017'] == 1)))
# Out:
# The number of states with 100% SAT participation rate is 4

# %%
#check for the states with lowest SAT participation rates in 2017 and 2018
display(sat_act_final[['sat_participation_2017']].sort_values(by=['sat_participation_2017'],ascending=True).head())

display(sat_act_final[['sat_participation_2018']].sort_values(by=['sat_participation_2018'],ascending=True).head())
# Out:
#               sat_participation_2017
# state
# North Dakota                    0.02
# Mississippi                     0.02
# Iowa                            0.02
# Missouri                        0.03
# Utah                            0.03
#               sat_participation_2018
# state
# North Dakota                    0.02
# Wyoming                         0.03
# South Dakota                    0.03
# Nebraska                        0.03
# Wisconsin                       0.03

# %%
#check for the states with lowest SAT participation rates in 2017 and 2018
display(sat_act_final[['act_participation_2017']].sort_values(by=['act_participation_2017'],ascending=True).head())

display(sat_act_final[['act_participation_2018']].sort_values(by=['act_participation_2018'],ascending=True).head())
# Out:
#                act_participation_2017
# state
# Maine                            0.08
# New Hampshire                    0.18
# Delaware                         0.18
# Rhode Island                     0.21
# Pennsylvania                     0.23
#                act_participation_2018
# state
# Maine                            0.07
# Rhode Island                     0.15
# New Hampshire                    0.16
# Delaware                         0.17
# Pennsylvania                     0.20

# %%
#viewing the participation rates in ascending order, with the SAT_participation_2018 columns only
display(sat_act_final[['act_participation_2018']].sort_values(by=['act_participation_2018'],ascending=True).head())
# Out:
#                act_participation_2018
# state
# Maine                            0.07
# Rhode Island                     0.15
# New Hampshire                    0.16
# Delaware                         0.17
# Pennsylvania                     0.20

# %% [markdown]
# #### States with more than 50% participation rates for both SAT/ACT

# %% [markdown]
# In both 2017 3 states were observed to have above 50% participation rates for SAT/ACT: Florida, Georgia and Hawaii. In 2018, in addition to the 3 states mentioned earlier, North Carolina and South Carolina also saw a higher than 50% participation rate in both SAT/ACT. Through this data, it is observed that ACT-mandated states (100% ACT participation rate) have seen an increase of SAT participation rates in North and South Carolina, suggesting that there may be an increased preference for the SAT.

# %%
#view participation rates higher than 50% for both SAT/ACT in 2017, with only the participation columns shown for clarity

display(sat_act_final[['sat_participation_2017','act_participation_2017']]
        [(sat_act_final['sat_participation_2017']>0.4) & (sat_act_final['act_participation_2017']>0.4)])
# Out:
#                 sat_participation_2017  act_participation_2017
# state
# Florida                           0.83                    0.73
# Georgia                           0.61                    0.55
# Hawaii                            0.55                    0.90
# North Carolina                    0.49                    1.00
# South Carolina                    0.50                    1.00
# Texas                             0.62                    0.45

# %%
#view participation rates higher than 50% for both SAT/ACT in 2017, with only the participation columns shown for clarity

display(sat_act_final[['sat_participation_2018','act_participation_2018']]
        [(sat_act_final['sat_participation_2018']>0.4) & (sat_act_final['act_participation_2018']>0.4)])
# Out:
#                 sat_participation_2018  act_participation_2018
# state
# Florida                           0.56                    0.66
# Georgia                           0.70                    0.53
# Hawaii                            0.56                    0.89
# Illinois                          0.99                    0.43
# North Carolina                    0.52                    1.00
# Oregon                            0.48                    0.42
# South Carolina                    0.55                    1.00
# Texas                             0.66                    0.45

# %% [markdown]
# #### Highest/Lowest Mean Scores (SAT/ACT)

# %% [markdown]
# Based on the dataframes generated below, it is observed that states with the SAT or ACT highest participation rates generally had the lowest average total scores, and vice versa. For instance in 2017, Minnesota (1295), Wisconsin (1291) and Iowa (1275) held the highest average SAT total scores, but had one of the lowest participation rates. Conversely, District of Columbia (950), Delaware (996) and Idaho (1005) held the lowest average SAT total scores, but had close to or 100% participation rates.
#
# Similarly, New Hampshire (25.5), Massachusetts (25.4) and Connecticut(25.2) held the highest average ACT composite scores, but had very low participation rates. Contrarily, Nevada (17.8), Mississipi (18.6) and South Carolina (18.7) held the lowest average ACT composite scores, but had 100% participation rates.
#
# This trend is continued in 2018, with one anomaly observed in West Virginia, as they ranked 3rd in the lowest average total SAT score, but only had a 28% participation rate.

# %%
#display the state with the HIGHEST mean SAT total score attained for 2017 and 2018
display(sat_act_final[['sat_total_2017','sat_participation_2017']]
        .sort_values(by=['sat_total_2017'],ascending=False).head())

display(sat_act_final[['sat_total_2018','sat_participation_2018']]
        .sort_values(by=['sat_total_2018'],ascending=False).head())
# Out:
#            sat_total_2017  sat_participation_2017
# state
# Minnesota            1295                    0.03
# Wisconsin            1291                    0.03
# Iowa                 1275                    0.02
# Missouri             1271                    0.03
# Kansas               1260                    0.04
#               sat_total_2018  sat_participation_2018
# state
# Minnesota               1298                    0.04
# Wisconsin               1294                    0.03
# North Dakota            1283                    0.02
# Iowa                    1265                    0.03
# Kansas                  1265                    0.04

# %%
#display the state with the LOWEST mean SAT total score attained for 2017 and 2018 with participation rates
display(sat_act_final[['sat_total_2017','sat_participation_2017']]
        .sort_values(by=['sat_total_2017'],ascending=True).head())

display(sat_act_final[['sat_total_2018','sat_participation_2018']]
        .sort_values(by=['sat_total_2018'],ascending=True).head())
# Out:
#                       sat_total_2017  sat_participation_2017
# state
# District of Columbia             950                    1.00
# Delaware                         996                    1.00
# Idaho                           1005                    0.93
# Michigan                        1005                    1.00
# Maine                           1012                    0.95
#                       sat_total_2018  sat_participation_2018
# state
# District of Columbia             977                    0.92
# Delaware                         998                    1.00
# West Virginia                    999                    0.28
# Idaho                           1001                    1.00
# Utah                            1010                    0.04

# %%
#display the state with the HIGHEST mean ACT composite score attained for 2017 and 2018 with participation rates
display(sat_act_final[['act_composite_2017','act_participation_2017']]
        .sort_values(by=['act_composite_2017'],ascending=False).head())

display(sat_act_final[['act_composite_2018','act_participation_2018']]
        .sort_values(by=['act_composite_2018'],ascending=False).head())
# Out:
#                       act_composite_2017  act_participation_2017
# state
# New Hampshire                       25.5                    0.18
# Massachusetts                       25.4                    0.29
# Connecticut                         25.2                    0.31
# Maine                               24.3                    0.08
# District of Columbia                24.2                    0.32
#                act_composite_2018  act_participation_2018
# state
# Connecticut                  25.6                    0.26
# Massachusetts                25.5                    0.25
# New Hampshire                25.1                    0.16
# New York                     24.5                    0.27
# Michigan                     24.2                    0.22

# %%
#display the state with the LOWEST mean ACT composite score attained for 2017 and 2018 with participation rates
display(sat_act_final[['act_composite_2017','act_participation_2017']].sort_values(by=['act_composite_2017'],ascending=True).head())

display(sat_act_final[['act_composite_2018','act_participation_2018']].sort_values(by=['act_composite_2018'],ascending=True).head())
# Out:
#                 act_composite_2017  act_participation_2017
# state
# Nevada                        17.8                     1.0
# Mississippi                   18.6                     1.0
# South Carolina                18.7                     1.0
# Hawaii                        19.0                     0.9
# North Carolina                19.1                     1.0
#                 act_composite_2018  act_participation_2018
# state
# Nevada                        17.7                    1.00
# South Carolina                18.3                    1.00
# Mississippi                   18.6                    1.00
# Hawaii                        18.9                    0.89
# Alabama                       19.1                    1.00

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# The aim of the correlation heatmap is to identify the relationship(s) between SAT/ACT participation rates and the average total/composite scores, and to provide a more advanced analysis.
#
# Based on the correlation heatmap below, participation rates appear to be negatively correlated with average total/composite scores, the same also applies to SAT participation rates with ACT participation rates. This suggests that students who are well-prepared are likelier to take the SAT/ACT in states where either of these tests is not mandated. This is also further exemplified by the high scores reflected in all the subjects taken. Contrarily, in states where SAT/ACT is mandatory, students may not be as motivated or well-prepared, thus resulting in a drastically lower average total/composite score.

# %%
plt.figure(figsize=(16, 12))
heatmap = sns.heatmap(sat_act_final.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Relationship between SAT/ACT participation rates and total/composite scores', fontdict={'fontsize':18}, pad=12);
# save heatmap as .png file
# dpi - sets the resolution of the saved image in dots/inches
# bbox_inches - when set to 'tight' - does not allow the labels to be cropped
plt.savefig('heatmap.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# In this section, the histograms are plotted below to provide a better understanding of the SAT/ACT participation rates and average total/composite scores.

# %%
# custom function for making histogram subplots
def subplot_histograms(dataframe, list_of_columns,list_of_titles,list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/4)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=4,figsize=(15, nrows+2),sharey=True) 
    
    # Ravel turns a matrix into a vector, which is easier to iterate
    ax = ax.ravel() 
    # Gives us an index value to get into all our lists
    for i, column in enumerate(list_of_columns): 
        ax[i].hist(dataframe[column],bins=15)
        ax[i].set_title(list_of_titles[i],fontsize=13)
        ax[i].set_xlabel(list_of_xlabels[i])
        
    plt.tight_layout()

# %% [markdown]
# #### Participation rates
# In the histograms plotted below, the distribution is observed to be bimodal - states either have a very high or very low participation rate, which is consistent with the earlier observation in the EDA (exploratory data analysis) on the number of states with more than 50% participation in both tests.

# %%
sat_act_final["sat_participation_2017"] = sat_act_final["sat_participation_2017"].apply(float_to_pct)
sat_act_final["act_participation_2017"] = sat_act_final["act_participation_2017"].apply(float_to_pct)
sat_act_final["sat_participation_2018"] = sat_act_final["sat_participation_2018"].apply(float_to_pct)
sat_act_final["act_participation_2018"] = sat_act_final["act_participation_2018"].apply(float_to_pct)
#convert the float values back to a percentage for the x-axis in our histogram below

# %%
#construct the histogram for SAT/ACT Participation Rates (2017/2018)
participation = ['sat_participation_2017','sat_participation_2018','act_participation_2017','act_participation_2018']
titles = ['SAT participation % (2017)','SAT participation % (2018)','ACT participation % (2017)','ACT participation % (2018)']
xlabels = ['','','','']
subplot_histograms(sat_act_final,participation,titles,xlabels)
plt.tight_layout()

# %% [markdown]
# ### Average total/composite scores for SAT/ACT
# Similarly, a bimodal distribution is observed in all the below histograms - the peaks tend to occur below the 50th percentile for SAT, whereas the peaks tend to occur around the 50th percentile of the distribution.

# %%
# total scores for SAT & ACT (2017/2018)
participation = ['sat_total_2017','sat_total_2018','act_composite_2017','act_composite_2018']
titles = ['SAT total score (2017)','SAT total score (2018)','ACT composite score (2017)','ACT composite score (2018)']
xlabels = ['','','','']
subplot_histograms(sat_act_final,participation,titles,xlabels,)
plt.tight_layout()

# %%
# Histograms: math and reading scores for SAT & ACT (2017)
participation = ['sat_math_2017','act_math_2017','sat_ebrw_2017','act_english_2017']
titles = ['SAT math scores (2017)','ACT math scores (2017)','SAT EBRW scores (2017)', 'ACT English scores (2017)']
xlabels = ['','','','']
subplot_histograms(sat_act_final,participation,titles,xlabels)
plt.tight_layout()

# %% [markdown]
# ### Boxplots
# In this section, the below boxplot diagrams are plotted to further illustrate and complement the information that we have gathered from the histograms above.

# %%
# set lists to split dataframe for plots
sat_scores_all = ['sat_ebrw_2017','sat_math_2017']
sat_scores_total = ['sat_total_2017','sat_total_2018']
act_scores_all = ['act_english_2017','act_math_2017','act_science_2017','act_composite_2017']
participation_total = ['sat_participation_2017','sat_participation_2018','act_participation_2017','act_participation_2018']

fig, ax = plt.subplots(2,2, figsize=(15, 10)) 

sns.boxplot(data=sat_act_final[sat_scores_all],ax = ax[0][0],orient='h')
ax[0][0].set_title('SAT scores 2017',fontsize=16)
plt.setp(ax[0][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=sat_act_final[sat_scores_total],ax = ax[0][1],orient='h')
ax[0][1].set_title('SAT total scores 2017',fontsize=16)
plt.setp(ax[0][1].get_xticklabels(), fontsize=14)

sns.boxplot(data=sat_act_final[act_scores_all],ax = ax[1][0],orient='h')
ax[1][0].set_title('ACT scores 2017',fontsize=16)
plt.setp(ax[1][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=sat_act_final[act_scores_all],ax = ax[1][0],orient='h')
ax[1][0].set_title('ACT scores 2017',fontsize=16)
plt.setp(ax[1][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=sat_act_final[participation_total],ax = ax[1][1],orient='h')
ax[1][1].set_title('ACT/SAT participations (2017/2018)',fontsize=16)
plt.setp(ax[1][1].get_xticklabels(), fontsize=14)

plt.tight_layout()

# %% [markdown]
# ### Scatterplot Diagrams
# In this section, the below scatterplot diagrams are plotted to further illustrate any relationship or correlation between similar subject scores, total/composite scores between SAT/ACT and total/composite scores in 2017 and 2018.

# %%
def scatterplot(df, var_1, var_2, x_label, y_label, fig_title):

    fig = sns.lmplot(x=var_1, y=var_2, data=df, height=6, palette="dict")

    
    plt.title(fig_title, fontsize=18)
    plt.xlabel(x_label, fontsize=14)
    plt.ylabel(y_label, fontsize=14)
    
    corr_val = sat_act_final[var_1].corr(sat_act_final[var_2])

# %% [markdown]
# #### Participation rates vs total score

# %%
scatterplot(
    sat_act_final,
    "sat_participation_2017", 
    "sat_total_2017", 
    "SAT Participation rates (2017)",
    "SAT total scores (2017)",
    "SAT Participation rates vs Total scores (2017)",
    )

# %%
scatterplot(
    sat_act_final,
    "act_participation_2017", 
    "act_composite_2017", 
    "ACT Participation rates (2017)",
    "ACT total scores (2017)",
    "ACT Participation rates vs Composite scores (2017)",
    )

# %%
scatterplot(
    sat_act_final,
    "sat_participation_2018", 
    "sat_total_2018", 
    "SAT Participation rates (2018)",
    "SAT total scores (2018)",
    "SAT Participation rates vs Total scores (2018)",
    )

# %%
scatterplot(
    sat_act_final,
    "act_participation_2018", 
    "act_composite_2018", 
    "ACT Participation rates (2018)",
    "ACT total scores (2018)",
    "ACT Participation rates vs Composite scores (2018)",
    )

# %% [markdown]
# Based on the diagrams above, it appears that there is a strong negative correlation between participation rates and total scores.

# %% [markdown]
# #### SAT vs ACT subject scores

# %%
scatterplot(
    sat_act_final,
    "sat_ebrw_2017", 
    "act_english_2017", 
    "SAT Evidence-based Reading and Writing",
    "ACT English",
    "Comparison of English scores in 2017",
    )

# %%
sns_scatter(
    sat_act_final,
    "sat_math_2017", 
    "act_math_2017", 
    "SAT Math",
    "ACT Math",
    "Comparison of English scores in 2017",
    )

# %% [markdown]
# Based on the above scatterplot diagrams, it appears that there is a weak negative correlation between similar subject scores (ACT Math vs SAT Math).

# %%
# comparing total/composite scores
scatterplot(
    sat_act_final,
    "sat_total_2017", 
    "act_composite_2017", 
    "SAT Total",
    "ACT Composite",
    "Comparison of SAT Total/ACT Composite scores in 2017"
    )

# %% [markdown]
# Based on the diagram above, it appears that there is a weak negative correlation between Total/Composite scores (SAT Total score vs ACT Composite score).

# %% [markdown]
# ### SAT Total Scores 2017/2018

# %%
# comparing ACT Composite scores
scatterplot(
    sat_act_final,
    "sat_total_2017", 
    "sat_total_2018", 
    "SAT 2017",
    "SAT 2018",
    "Comparison of SAT Total scores (2017 vs 2018)"
    )

# %%
# comparing ACT Composite scores
scatterplot(
    sat_act_final,
    "act_composite_2017", 
    "act_composite_2018", 
    "ACT 2017",
    "ACT 2018",
    "Comparison of ACT Composite scores (2017 vs 2018)"
    )

# %% [markdown]
# Based on the above diagrams, there is a strong positive correlation in SAT/ACT total scores between 2017 and 2018.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# For ACT-mandated states, it is unlikely that efforts spent there will yield any satisfactory results. Resources can be focused on states such as California, Georgia or Oregon, where SAT and ACT participation rates remain low.
#
# Another recommendation would be to offer SAT tests at no cost to students, a move administered by [Delaware to promote a school culture to encourage more students to pursue education after high school]("https://delawarepta.org/free-sat-registration-now-open-for-public-school-juniors/") - the results of this funding speaks for itself in the datasets above with 100% participate rate in 2017 and 2018 from said state, 7 years after it kickstarted.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
